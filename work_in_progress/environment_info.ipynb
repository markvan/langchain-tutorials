# %%
# !which python3
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3

# %%
# !which pip3
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/pip3

# %%
# !find / -name sqlite 2>/dev/null
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlalchemy/dialects/sqlite
# /System/Volumes/Data/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlalchemy/dialects/sqlite
# /System/Volumes/Data/Users/mac1/Library/Application Support/JetBrains/IntelliJIdea2023.1/plugins/python/helpers/typeshed/stubs/SQLAlchemy/sqlalchemy/dialects/sqlite
# /System/Volumes/Data/Users/mac1/PycharmProjects/ask-multiple-pdfs/venv/lib/python3.9/site-packages/sqlalchemy/dialects/sqlite
# /System/Volumes/Data/Users/mac1/IdeaProjects/try-intellij-python/venv/lib/python3.9/site-packages/sqlalchemy/dialects/sqlite
# /System/Volumes/Data/Applications/PyCharm.app/Contents/plugins/python/helpers/typeshed/stubs/SQLAlchemy/sqlalchemy/dialects/sqlite
# /System/Volumes/Data/opt/anaconda3/pkgs/sqlalchemy-1.3.20-py38h9ed2024_0/lib/python3.8/site-packages/sqlalchemy/dialects/sqlite
# ...

# %%
# !ls /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12
# Out:
# LICENSE.txt                      modulefinder.py
# __future__.py                    multiprocessing
# __hello__.py                     netrc.py
# __phello__                       nntplib.py
# __pycache__                      ntpath.py
# _aix_support.py                  nturl2path.py
# _collections_abc.py              numbers.py
# _compat_pickle.py                opcode.py
# _compression.py                  operator.py
# _markupbase.py                   optparse.py
# _osx_support.py                  os.py
# _py_abc.py                       pathlib.py
# _pydatetime.py                   pdb.py
# _pydecimal.py                    pickle.py
# _pyio.py                         pickletools.py
# _pylong.py                       pipes.py
# _sitebuiltins.py                 pkgutil.py
# _strptime.py                     platform.py
# _sysconfigdata__darwin_darwin.py plistlib.py
# _threading_local.py              poplib.py
# _weakrefset.py                   posixpath.py
# ...

# %%
# !ls /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Out:
# Babel-2.13.1.dist-info
# Crypto
# Deprecated-1.2.14.dist-info
# GitPython-3.1.40.dist-info
# HyperPyYAML-1.2.2.dist-info
# IPython
# Jinja2-3.1.2.dist-info
# Mako-1.3.0.dist-info
# Markdown-3.5.1.dist-info
# MarkupSafe-2.1.3.dist-info
# OleFileIO_PL.py
# PIL
# Pillow-10.1.0.dist-info
# PyPika-0.48.9.dist-info
# PyYAML-6.0.1.dist-info
# Pygments-2.16.1.dist-info
# QtPy-2.4.1.dist-info
# README.txt
# Rtree-1.1.0.dist-info
# SQLAlchemy-2.0.22.dist-info
# Send2Trash-1.8.2.dist-info
# XlsxWriter-3.1.9.dist-info
# __pycache__
# _argon2_cffi_bindings
# _cffi_backend.cpython-312-darwin.so
# _distutils_hack
# _multiprocess
# _pulsar.cpython-312-darwin.so
# _ruamel_yaml.cpython-312-darwin.so
# _soundfile.py
# _soundfile_data
# _watchdog_fsevents.cpython-312-darwin.so
# _yaml
# aenum
# aenum-3.1.15.dist-info
# aiohttp
# aiohttp-3.9.1.dist-info
# aiosignal
# aiosignal-1.3.1.dist-info
# aiostream
# aiostream-0.5.2.dist-info
# alembic
# alembic-1.13.1.dist-info
# alphashape
# ...
